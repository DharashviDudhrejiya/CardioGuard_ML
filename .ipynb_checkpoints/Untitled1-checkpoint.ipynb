# %%
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import sklearn

# %%
df = pd.read_csv('cardio_train_cleaned.csv', delimiter=';')

# %%
import numpy as np

class LogisticRegressionFromScratch:
    def __init__(self, learning_rate=0.01, n_iters=1000):
        self.lr = learning_rate
        self.n_iters = n_iters
        self.weights = None
        self.bias = None
        self.train_losses = []

    # 1. Sigmoid Activation Function
    def _sigmoid(self, x):
        return 1 / (1 + np.exp(-x))

    # 2. Training (Fit)
    def fit(self, X, y):
        n_samples, n_features = X.shape
        
        # Initialize weights and bias to zeros
        self.weights = np.zeros(n_features)
        self.bias = 0

        # Gradient Descent
        for _ in range(self.n_iters):
            # Linear prediction (z = wx + b)
            linear_model = np.dot(X, self.weights) + self.bias
            # Activation (probabilities)
            y_predicted = self._sigmoid(linear_model)

            # Compute Gradients
            # dw = (1/n) * X.T * (y_pred - y)
            dw = (1 / n_samples) * np.dot(X.T, (y_predicted - y))
            db = (1 / n_samples) * np.sum(y_predicted - y)

            # Update Parameters
            self.weights -= self.lr * dw
            self.bias -= self.lr * db

    # 3. Prediction
    def predict(self, X):
        linear_model = np.dot(X, self.weights) + self.bias
        y_predicted = self._sigmoid(linear_model)
        y_predicted_cls = [1 if i > 0.5 else 0 for i in y_predicted]
        return np.array(y_predicted_cls)

    # 4. Accuracy Helper
    def score(self, X, y):
        y_pred = self.predict(X)
        return np.mean(y_pred == y)

print("✅ Logistic Regression Class defined successfully.")
# Out:
# ✅ Logistic Regression Class defined successfully.

# %%
# Initialize Model
# We use inputs from your existing variables
# Ensure X_train_final and y_train are numpy arrays (if they are pandas DFs)
X_train_np = X_train_final.values
X_test_np = X_test_final.values
y_train_np = y_train.values
y_test_np = y_test.values

print("Training Custom Logistic Regression...")
model = LogisticRegressionFromScratch(learning_rate=0.1, n_iters=2000)
model.fit(X_train_np, y_train_np)

# Predictions
predictions = model.predict(X_test_np)

# Compute Metrics Manually
tp = np.sum((predictions == 1) & (y_test_np == 1))
tn = np.sum((predictions == 0) & (y_test_np == 0))
fp = np.sum((predictions == 1) & (y_test_np == 0))
fn = np.sum((predictions == 0) & (y_test_np == 1))

accuracy = (tp + tn) / (tp + tn + fp + fn)
precision = tp / (tp + fp) if (tp + fp) > 0 else 0
recall = tp / (tp + fn) if (tp + fn) > 0 else 0
f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

print("\n📊 TEST RESULTS (From Scratch Implementation)")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Initialize Model
#       2 # We use inputs from your existing variables
#       3 # Ensure X_train_final and y_train are numpy arrays (if they are pandas DFs)
# ----> 4 X_train_np = X_train_final.values
#       5 X_test_np = X_test_final.values
#       6 y_train_np = y_train.values
#
# NameError: name 'X_train_final' is not defined
